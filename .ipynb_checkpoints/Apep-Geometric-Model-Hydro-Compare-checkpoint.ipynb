# %%
import xenomorph as xm
import xenomorph.systems as wrb
import xenomorph.geometry as gm

import numpy as np
import matplotlib.pyplot as plt

# %%
system = wrb.apep.copy()

system['phase'] = 1.02
system['az_amp'] = 0
system['lum_power'] = 0.5
system['comp_reduction'] = 0
system['histmax'] = 1

system
# Out:
# {'m1': 15.0,
#  'm2': 10.0,
#  'eccentricity': 0.82,
#  'inclination': 23.8,
#  'asc_node': 164.1,
#  'arg_peri': 10.6,
#  'open_angle': 126.0,
#  'period': 193.0,
#  'distance': 2400.0,
#  'windspeed1': 1024.0,
#  'windspeed2': 2400.0,
#  'turn_on': -108.0,
#  'turn_off': 141.0,
#  'gradual_turn': 0.1,
#  'oblate': 0.0,
#  'nuc_dist': 1.0,
#  'opt_thin_dist': 2.0,
#  'term_windspeed': 860,
#  'accel_rate': -5.0,
#  'orb_sd': 0.0,
#  'orb_amp': 0.0,
#  'orb_min': 180.0,
#  'az_sd': 30.0,
#  'az_amp': 0,
#  'az_min': 90.0,
#  'comp_incl': 124.0,
#  'comp_az': 238.8,
#  'comp_open': 90.0,
#  'comp_reduction': 0,
#  'comp_plume': 1.0,
#  'comp_plume_sd': 20.0,
#  'comp_plume_max': 373.0,
#  'phase': 1.02,
#  'sigma': 2.0,
#  'histmax': 1,
#  'lum_power': 0.5,
#  'spin_inc': 0.0,
#  'spin_Omega': 0.0,
#  'windspeed_polar': 2400,
#  'aniso_vel_mult': -6.2,
#  'aniso_vel_power': 3.53,
#  'open_angle_polar': 180.0,
#  'aniso_OA_mult': -6.05,
#  'aniso_OA_power': 3.53,
#  'star1amp': 0.7,
#  'star1sd': -0.7,
#  'star2amp': 0.7,
#  'star2sd': -0.7,
#  'star3amp': 0.7,
#  'star3sd': -1.12,
#  'star3dist': 1700.0,
#  'star1lum': 5.34,
#  'star1temp': 70000,
#  'star2lum': 5.3,
#  'star2temp': 85000,
#  'star3lum': 5.9,
#  'star3temp': 28000,
#  'amin': 0.001,
#  'amax': 0.5,
#  'dust_grain_beta': 1,
#  'dust_grain_b': 5,
#  'dust_grain_c': 0.05,
#  'dust_grain_max_val': 2,
#  'dust_grain_d': 0.2,
#  'dust_mass_beta': 1,
#  'dust_mass_b': 5,
#  'dust_mass_c': 0.1,
#  'dust_mass_max_val': 1.1e-10}

# %%
particles, weights = gm.dust_plume(system) 
n = 0.4

particles = particles[:, :int(n * particles.shape[1])]
weights = weights[:int(n * len(weights))] 
X, Y, H = gm.smooth_histogram2d(particles, weights, system)

X = system['distance'] * 206265 * np.tan(X * 4.84814e-6)
Y = system['distance'] * 206265 * np.tan(Y * 4.84814e-6)

# %%
fig, ax = plt.subplots(figsize=(9, 9))
ax.pcolormesh(X, Y, H, cmap='hot', rasterized=True)
ax.set(aspect='equal', ylabel='x (au)', xlabel='y (au)')
# Out:
# [None, Text(0, 0.5, 'x (au)'), Text(0.5, 0, 'y (au)')]

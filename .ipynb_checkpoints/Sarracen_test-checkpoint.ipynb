# %%
import sarracen
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# set code units
_density = 5.941E-07 # g/cm^3
_mass = 1.989E+33 # g       
_length = 1.496E+13 # cm    
_time = 5.023E+06 # s
_energy = 1.765E+46 # erg
_velocity = 2.978E+06 # cm/s    
_opacity = 1.125E-07 # cm^2/g
_G = 1.000E+00              
_c = 1.007E+04       
_mu_0 = 1.000E+00
_a = 1.435E-21

# useful constants
cm_to_au = 6.68459e-14

# %%
sdf, sdf_sinks = sarracen.read_phantom('Data/Phantom-Dumps/apep-periastron-isotherm_00107')

# %%
sdf
# Out:
#            iorig  iseed_sink          x         y         z         vx  \
# 0              1           1   9.539463 -1.543802  0.428569  29.964643
# 1              2           1   9.870266 -1.463478  0.200541  63.997228
# 2              3           1   9.633969 -1.322969  0.721923  39.687355
# 3              4           1   9.433481 -1.647314  0.110135  19.061429
# 4              5           1  10.078634 -1.208187  0.390306  85.433860
# ...          ...         ...        ...       ...       ...        ...
# 5097757  8355417           1  11.316298  0.008132 -1.971409  83.744246
# 5097758  8355418           1   9.606726 -0.844002 -2.865337  14.636198
# 5097759  8355419           1  11.131356 -1.419692 -2.025115  76.268089
# 5097760  8355420           1  10.564636 -0.139741 -2.561824  53.358907
# 5097761  8355421           1  10.393443 -1.167263 -2.592336  46.438563
#
#                  vy          vz         u     Tdust         h  alpha  \
# 0       -104.509403   44.090520  0.000625  9.927842  0.527141    0.0
# 1        -96.245775   20.631321  0.000625  9.927842  0.528946    0.0
# 2        -81.790428   74.270351  0.000625  9.927842  0.529782    0.0
# 3       -115.158568   11.330504  0.000625  9.927842  0.525283    0.0
# 4        -69.981764   40.154134  0.000625  9.927842  0.531842    0.0
# ...             ...         ...       ...       ...       ...    ...
# 5097757   21.833565  -79.692578  0.000626  9.927842  0.847166    0.0
# 5097758  -12.613239 -115.828906  0.000626  9.927842  0.841900    0.0
# 5097759  -35.885012  -81.863625  0.000626  9.927842  0.853393    0.0
# 5097760   15.855943 -103.559623  0.000626  9.927842  0.848224    0.0
# 5097761  -25.680790 -104.793041  0.000626  9.927842  0.842788    0.0
#
#                divv
# 0        234.161850
# 1        233.798676
# 2        232.864471
# 3        234.278000
# 4        232.977142
# ...             ...
# 5097757   78.856422
# 5097758   79.819176
# 5097759   78.986458
# 5097760   79.321815
# 5097761   80.090919
#
# [5017051 rows x 13 columns]

# %%
fig, ax = plt.subplots(figsize=(15,15))
lim = (-1000, 1000)
ax = sdf.render('rho', ax=ax, log_scale=True, xlim=lim, ylim=lim, rotation=[0, 90, 00])
# Out:
# C:\Users\ryanw\AppData\Local\Temp\ipykernel_16680\3129633911.py:3: DeprecationWarning: The default rotation point is currently the midpoint of the x/y/z bounds, but will change to [x, y, z] = [0, 0, 0] in Sarracen version 1.3.0.
#   ax = sdf.render('rho', ax=ax, log_scale=True, xlim=lim, ylim=lim, rotation=[0, 90, 00])

# %%
ax
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sdf_new = sdf.copy()
sdf_new.calc_density()
sdf_new
# Out:
#            iorig  iseed_sink          x         y         z         vx  \
# 0              1           1   9.539463 -1.543802  0.428569  29.964643
# 1              2           1   9.870266 -1.463478  0.200541  63.997228
# 2              3           1   9.633969 -1.322969  0.721923  39.687355
# 3              4           1   9.433481 -1.647314  0.110135  19.061429
# 4              5           1  10.078634 -1.208187  0.390306  85.433860
# ...          ...         ...        ...       ...       ...        ...
# 5097757  8355417           1  11.316298  0.008132 -1.971409  83.744246
# 5097758  8355418           1   9.606726 -0.844002 -2.865337  14.636198
# 5097759  8355419           1  11.131356 -1.419692 -2.025115  76.268089
# 5097760  8355420           1  10.564636 -0.139741 -2.561824  53.358907
# 5097761  8355421           1  10.393443 -1.167263 -2.592336  46.438563
#
#                  vy          vz         u     Tdust         h  alpha  \
# 0       -104.509403   44.090520  0.000625  9.927842  0.527141    0.0
# 1        -96.245775   20.631321  0.000625  9.927842  0.528946    0.0
# 2        -81.790428   74.270351  0.000625  9.927842  0.529782    0.0
# 3       -115.158568   11.330504  0.000625  9.927842  0.525283    0.0
# 4        -69.981764   40.154134  0.000625  9.927842  0.531842    0.0
# ...             ...         ...       ...       ...       ...    ...
# 5097757   21.833565  -79.692578  0.000626  9.927842  0.847166    0.0
# 5097758  -12.613239 -115.828906  0.000626  9.927842  0.841900    0.0
# 5097759  -35.885012  -81.863625  0.000626  9.927842  0.853393    0.0
# 5097760   15.855943 -103.559623  0.000626  9.927842  0.848224    0.0
# 5097761  -25.680790 -104.793041  0.000626  9.927842  0.842788    0.0
#
#                divv           rho
# 0        234.161850  2.924910e-09
# 1        233.798676  2.895063e-09
# 2        232.864471  2.881388e-09
# 3        234.278000  2.956056e-09
# 4        232.977142  2.848024e-09
# ...             ...           ...
# 5097757   78.856422  7.046718e-10
# 5097758   79.819176  7.179792e-10
# 5097759   78.986458  6.893602e-10
# 5097760   79.321815  7.020381e-10
# 5097761   80.090919  7.157101e-10
#
# [5017051 rows x 14 columns]

# %%
gamma = 1.1
sdf_new['P'] = (gamma - 1) * sdf_new['rho'] * sdf_new['u']
sdf_new['r'] = np.sqrt(sdf_new['x']**2 + sdf_new['y']**2 + sdf_new['z']**2)
sdf_new
# Out:
#            iorig  iseed_sink          x         y         z         vx  \
# 0              1           1   9.539463 -1.543802  0.428569  29.964643
# 1              2           1   9.870266 -1.463478  0.200541  63.997228
# 2              3           1   9.633969 -1.322969  0.721923  39.687355
# 3              4           1   9.433481 -1.647314  0.110135  19.061429
# 4              5           1  10.078634 -1.208187  0.390306  85.433860
# ...          ...         ...        ...       ...       ...        ...
# 5097757  8355417           1  11.316298  0.008132 -1.971409  83.744246
# 5097758  8355418           1   9.606726 -0.844002 -2.865337  14.636198
# 5097759  8355419           1  11.131356 -1.419692 -2.025115  76.268089
# 5097760  8355420           1  10.564636 -0.139741 -2.561824  53.358907
# 5097761  8355421           1  10.393443 -1.167263 -2.592336  46.438563
#
#                  vy          vz         u     Tdust         h  alpha  \
# 0       -104.509403   44.090520  0.000625  9.927842  0.527141    0.0
# 1        -96.245775   20.631321  0.000625  9.927842  0.528946    0.0
# 2        -81.790428   74.270351  0.000625  9.927842  0.529782    0.0
# 3       -115.158568   11.330504  0.000625  9.927842  0.525283    0.0
# 4        -69.981764   40.154134  0.000625  9.927842  0.531842    0.0
# ...             ...         ...       ...       ...       ...    ...
# 5097757   21.833565  -79.692578  0.000626  9.927842  0.847166    0.0
# 5097758  -12.613239 -115.828906  0.000626  9.927842  0.841900    0.0
# 5097759  -35.885012  -81.863625  0.000626  9.927842  0.853393    0.0
# 5097760   15.855943 -103.559623  0.000626  9.927842  0.848224    0.0
# 5097761  -25.680790 -104.793041  0.000626  9.927842  0.842788    0.0
#
#                divv           rho             P          r
# 0        234.161850  2.924910e-09  1.828858e-13   9.673073
# 1        233.798676  2.895063e-09  1.810199e-13   9.980187
# 2        232.864471  2.881388e-09  1.801659e-13   9.751143
# 3        234.278000  2.956056e-09  1.848332e-13   9.576865
# 4        232.977142  2.848024e-09  1.780796e-13  10.158293
# ...             ...           ...           ...        ...
# 5097757   78.856422  7.046718e-10  4.410268e-14  11.486737
# 5097758   79.819176  7.179792e-10  4.493528e-14  10.060402
# 5097759   78.986458  6.893602e-10  4.314435e-14  11.402793
# 5097760   79.321815  7.020381e-10  4.393773e-14  10.871706
# 5097761   80.090919  7.157101e-10  4.479319e-14  10.775266
#
# [5017051 rows x 16 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 10))

# colour_vals = np.log10(sdf_new['Tdust'])
# norm_values = colour_vals - np.min(colour_vals)
# norm_values /= np.max(norm_values)
# cmap = 'viridis'
# rgb = mpl.colormaps[cmap](norm_values)

# ax.plot(sdf_new['r'] * _length * cm_to_au, sdf_new['P'] * _density * _energy / _mass, linestyle='', marker=',', markersize=1e-8)
ax.scatter(sdf_new['r'] * _length * cm_to_au, sdf_new['P'] * _density * _energy / _mass, c=np.log10(sdf_new['Tdust']), cmap='viridis',
           marker=',', s=1e-3)
ax.set(xscale='log', yscale='log',
      xlabel='Radius (au)', ylabel=r'Pressure (erg/cm$^3$)')
# Out:
# [None,
#  None,
#  Text(0.5, 0, 'Radius (au)'),
#  Text(0, 0.5, 'Pressure (erg/cm$^3$)')]
